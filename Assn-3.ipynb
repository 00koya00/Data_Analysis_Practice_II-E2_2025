# %% [markdown]
# # Assn-3
#
# **Goal**: Use Jupyter to reproduce the figures below including:
#
# * Colors
# * Labels
# * etc.

# %% [markdown]
# ___
#
# ### Figure 1
#
# Use `data-fig1.npy` for this figure.

# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt

a   = np.load( 'Assn-3-data/data-fig1.npy' )

# enter additional commands here to reproduce the figure below

plt.plot(a, color = 'black', marker = "o")
plt.ylabel("Value")
plt.xlabel("Time")
plt.show()

# NOTE!
# - Entering commands and running the cell may cause the figure to disapper
# - If the figure disappears, use Assn-3.html as a reference

# %% [markdown]
# ___
#
# ### Figure 2
#
# Use `data-fig2.npy` for this figure.

# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt

a   = np.load( 'Assn-3-data/data-fig2.npy' )

R = []
G = []
B = []
for i in range (0, len(a)):
    R.append(a[i,0])
    G.append(a[i,1])
    B.append(a[i,2])

plt.plot(R, color = 'red', label="Red" )
plt.plot(G, color = 'green', label="Green" )
plt.plot(B, color = 'blue', label="Blue" )

plt.xlabel("X value")
plt.ylabel("Y value")
plt.legend(loc=2)
plt.show()

# %% [markdown]
# ___
#
# ### Figure 3
#
# Use `data-fig3.npy` for this figure.

# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt

a   = np.load( 'Assn-3-data/data-fig3.npy' )

x = []
y = []

for i in range (0, len(a)):
    x.append(a[i,0])
    y.append(a[i,1])

plt.scatter(x,y, s = 200, c = "blue", edgecolors = "blue", alpha = 0.3)

plt.xlabel("X value")
plt.ylabel("Y value")
plt.show()

# %% [markdown]
# ___
#
# ### Figure 4
#
# Use `data-fig4.npy` for this figure.

# %%
# %matplotlib inline

import numpy as np
from matplotlib import pyplot as plt

a   = np.load( 'Assn-3-data/data-fig4.npy' )

plt.bar(["A", "B", "C", "D", "E"], height = a, color = "#b3b3b3" )


plt.xlabel("Category")
plt.ylabel("Value")
plt.show()

# %% [markdown]
# ___
#
# ### Figure 5
#
# Use `data-fig5.npy` for this figure.
#
# *Hint*: Use 2D visualization and the "RdBu" colormap.

# %%
# %matplotlib inline

import matplotlib
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
import matplotlib.cbook as cbook
import matplotlib.cm as cm

a   = np.load( 'Assn-3-data/data-fig5.npy' )

fig, ax = plt.subplots()
im = ax.imshow(a, cmap=cm.RdBu,
               origin="lower", extent=[0, 40 , 0, 120], aspect = "auto",
               vmax=abs(a).max(), vmin=-abs(a).max(),
              )


fig.colorbar(im, ax=ax)
plt.show()

# %% [markdown]
# ___
#
# ### UNGRADED BONUS QUESTION
#
# (This question is an *optional*, *ungraded* bonus problem.)
#
# Use `data-fig-bonus-X.npy`, `data-fig-bonus-Y.npy` and `data-fig-bonus-Z.npy` for this figure.
#
# *Hint*: Search Matplotlib's online examples.

# %%
import matplotlib.pyplot as plt

from matplotlib import cm
from mpl_toolkits.mplot3d import axes3d


ax = plt.figure().add_subplot(projection='3d')

X = np.load('Assn-3-data/data-fig-bonus-X.npy')
Y = np.load('Assn-3-data/data-fig-bonus-Y.npy')
Z = np.load('Assn-3-data/data-fig-bonus-Z.npy')

ax.contour(X, Y, Z, extend3d=True, cmap=cm.coolwarm)

plt.show()
